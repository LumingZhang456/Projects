# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# # Data analyses and Visualizations

# %% [markdown]
# The dataset is the tweet archive of Twitter user [@dog_rate](https://twitter.com/dog_rates), also known as [WeRateDogs](https://en.wikipedia.org/wiki/WeRateDogs). WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog.

# %% [markdown]
# ## Insights

# %% [markdown]
# ### 1.  Frequency of each source types
#
# ![1-2.png](attachment:1-2.png)
#
# There are three different source types for tweet users, which are __mobile, web and tweetdeck__. From the above plot, we can see that __mobile__ is the most used source type among tweet users. From this result, we may consider to pay more attention on mobile users to get more clients.

# %% [markdown]
# ### 2. Relationship between Retweet and Favorite
#
# ![2-2.png](attachment:2-2.png)
#
# The above scatter plot shows that there is a very strong positive correlation between favorite and retweet. The correlation coefficient between these two variables is 0.912947, which is close to 1. Therefore, we can conclude that, with increasing number of favorite, the number of retweet goes up, which can bring more profits

# %% [markdown]
# ### 3. Correlations
#
# ![3.png](attachment:3.png)
#
# The correlation scatter plot is useful for finding connections between variables. The correlation coefficient range from -1 to 1. The larger number, the stronger correlation. The positive and negative of the number present whether it is a positive or negative correlation.  The correlation coefficient bewtween __p1_conf__ and __p2_conf__ is -0.509531, which shows a negative correlation between those two variables. The correlation coefficient bewtween __p1_conf__ and __p3_conf__ is  -0.707994, which shows that there is negative correlation between those two variables. This means that the more confident the result of the first image, the less likely the following images would accurately guess the breed of dog.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ![4-2.png](attachment:4-2.png)
#
# There are hundreds of different dog names in those tweets. So the question came up. What is the most popular dog name among tweet users? Here is the histogram of the Top 9 popular dog names. There is not a high gap between each other since the number of each name has similar value. But we can clearly see that 'Charlie' is the most popular dog name among those hundreds of dog names.
